# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-madhu-0409/prodigy-infotech-internship/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Message": [
        "I love this product! It's amazing.",
        "Worst service ever. I am very disappointed.",
        "Nothing special about it.",
        "Absolutely fantastic experience!",
        "The item broke after one day.",
        "Pretty decent for the price.",
        "I hate this so much!",
        "Well done, team!",
        "It was okay, not too bad.",
        "Terrible delivery time!"
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                                        Message
# 0           I love this product! It's amazing.
# 1  Worst service ever. I am very disappointed.
# 2                    Nothing special about it.
# 3             Absolutely fantastic experience!
# 4                The item broke after one day.

# %%
def get_sentiment(text):
    polarity = TextBlob(str(text)).sentiment.polarity
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply function
df['Sentiment'] = df['Message'].apply(get_sentiment)
df
# Out:
#                                        Message Sentiment
# 0           I love this product! It's amazing.  Positive
# 1  Worst service ever. I am very disappointed.  Negative
# 2                    Nothing special about it.  Positive
# 3             Absolutely fantastic experience!  Positive
# 4                The item broke after one day.   Neutral
# 5                 Pretty decent for the price.  Positive
# 6                         I hate this so much!  Negative
# 7                             Well done, team!   Neutral
# 8                    It was okay, not too bad.  Negative
# 9                      Terrible delivery time!  Negative
